# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import f1_score, accuracy_score  # Added accuracy_score import

# Step 1: Load the dataset
df = pd.read_csv("WineQT.csv")

# Step 2: Drop the 'Id' column (not needed)
df.drop(columns=["Id"], inplace=True)

# Step 3: Separate features (X) and target (y)
X = df.drop(columns=["quality"])  # Features
y = df["quality"]  # Target variable (discrete classes)

# Step 4: Map target labels to a range of [0, num_classes - 1]
unique_classes = y.unique()
num_classes = len(unique_classes)
label_mapping = {label: idx for idx, label in enumerate(sorted(unique_classes))}
y_mapped = y.map(label_mapping)

# Step 5: Perform Z-score normalization (standardization)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Convert the scaled features back to a DataFrame
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)

# Step 6: Split the data into training and test sets (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(X_scaled_df, y_mapped, test_size=0.2, random_state=42)

# Step 7: Define the base model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),  # Input layer
    Dense(32, activation='relu'),  # Hidden layer
    Dense(16, activation='relu'),  # Hidden layer
    Dense(num_classes, activation='softmax')  # Output layer (num_classes)
])

# Step 8: Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Step 9: Define a custom callback to track F1-score
class F1ScoreCallback(Callback):
    def __init__(self, X_train, y_train, X_val, y_val):
        super(F1ScoreCallback, self).__init__()
        self.X_train = X_train
        self.y_train = y_train
        self.X_val = X_val
        self.y_val = y_val
        self.train_f1_scores = []
        self.val_f1_scores = []

    def on_epoch_end(self, epoch, logs=None):
        # Predict on training data
        y_train_pred = self.model.predict(self.X_train)
        y_train_pred = tf.argmax(y_train_pred, axis=1).numpy()
        train_f1 = f1_score(self.y_train, y_train_pred, average='weighted')
        self.train_f1_scores.append(train_f1)

        # Predict on validation data
        y_val_pred = self.model.predict(self.X_val)
        y_val_pred = tf.argmax(y_val_pred, axis=1).numpy()
        val_f1 = f1_score(self.y_val, y_val_pred, average='weighted')
        self.val_f1_scores.append(val_f1)

        # Print F1-scores
        print(f"Epoch {epoch+1}: Train F1-Score = {train_f1:.4f}, Val F1-Score = {val_f1:.4f}")

# Step 10: Split training data into training and validation sets
X_train_train, X_val, y_train_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Step 11: Initialize the F1-score callback
f1_callback = F1ScoreCallback(X_train_train, y_train_train, X_val, y_val)

# Step 12: Train the model with the F1-score callback
history = model.fit(
    X_train_train, y_train_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[f1_callback],
    verbose=1
)

# Step 13: Evaluate the model on the test set
y_pred = model.predict(X_test)
y_pred = tf.argmax(y_pred, axis=1).numpy()
accuracy = accuracy_score(y_test, y_pred)  # Now this will work
test_f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test F1-Score: {test_f1:.4f}")
# Out:
# Epoch 1/50
# 23/23 [==============================] - 0s 3ms/steposs: 1.6196 - accuracy: 0.3
# 6/6 [==============================] - 0s 5ms/step
# Epoch 1: Train F1-Score = 0.4131, Val F1-Score = 0.3817
# 23/23 [==============================] - 2s 45ms/step - loss: 1.5700 - accuracy: 0.3926 - val_loss: 1.4024 - val_accuracy: 0.4754
# Epoch 2/50
# 23/23 [==============================] - 0s 3ms/steposs: 1.2590 - accuracy: 0.
# 6/6 [==============================] - 0s 3ms/step
# Epoch 2: Train F1-Score = 0.4974, Val F1-Score = 0.4269
# 23/23 [==============================] - 1s 30ms/step - loss: 1.2397 - accuracy: 0.5376 - val_loss: 1.2567 - val_accuracy: 0.5027
# Epoch 3/50
# 23/23 [==============================] - 0s 3ms/steposs: 1.1018 - accuracy: 0.
# 6/6 [==============================] - 0s 2ms/step
# Epoch 3: Train F1-Score = 0.5218, Val F1-Score = 0.4371
# 23/23 [==============================] - 1s 30ms/step - loss: 1.1040 - accuracy: 0.5568 - val_loss: 1.1825 - val_accuracy: 0.5082
# Epoch 4/50
# 23/23 [==============================] - 0s 2ms/steposs: 1.0617 - accuracy: 0.59
# 6/6 [==============================] - 0s 2ms/step
# Epoch 4: Train F1-Score = 0.5276, Val F1-Score = 0.4438
# 23/23 [==============================] - 1s 26ms/step - loss: 1.0265 - accuracy: 0.5882 - val_loss: 1.1294 - val_accuracy: 0.5137
# Epoch 5/50
# 23/23 [==============================] - 0s 2ms/steposs: 0.9854 - accuracy: 0.59
# 6/6 [==============================] - 0s 3ms/step
# Epoch 5: Train F1-Score = 0.5733, Val F1-Score = 0.5326
# 23/23 [==============================] - 1s 25ms/step - loss: 0.9812 - accuracy: 0.6019 - val_loss: 1.0973 - val_accuracy: 0.5683
# Epoch 6/50
# 23/23 [==============================] - 0s 2ms/steposs: 0.9068 - accuracy: 0.62
# 6/6 [==============================] - 0s 2ms/step
# Epoch 6: Train F1-Score = 0.6108, Val F1-Score = 0.5517
# 23/23 [==============================] - 1s 27ms/step - loss: 0.9552 - accuracy: 0.6170 - val_loss: 1.0613 - val_accuracy: 0.5792
# Epoch 7/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.8566 - accuracy: 0.
# 6/6 [==============================] - 0s 5ms/step
# Epoch 7: Train F1-Score = 0.5889, Val F1-Score = 0.5498
# 23/23 [==============================] - 1s 27ms/step - loss: 0.9320 - accuracy: 0.6293 - val_loss: 1.0782 - val_accuracy: 0.5792
# Epoch 8/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.9143 - accuracy: 0.
# 6/6 [==============================] - 0s 5ms/step
# Epoch 8: Train F1-Score = 0.6192, Val F1-Score = 0.5569
# 23/23 [==============================] - 1s 27ms/step - loss: 0.9164 - accuracy: 0.6334 - val_loss: 1.0645 - val_accuracy: 0.5847
# Epoch 9/50
# 23/23 [==============================] - 0s 2ms/steposs: 0.9177 - accuracy: 0.
# 6/6 [==============================] - 0s 3ms/step
# Epoch 9: Train F1-Score = 0.6177, Val F1-Score = 0.5518
# 23/23 [==============================] - 1s 27ms/step - loss: 0.9051 - accuracy: 0.6375 - val_loss: 1.0614 - val_accuracy: 0.5792
# Epoch 10/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.9046 - accuracy: 0.
# 6/6 [==============================] - 0s 9ms/step
# Epoch 10: Train F1-Score = 0.6305, Val F1-Score = 0.5415
# 23/23 [==============================] - 1s 29ms/step - loss: 0.8928 - accuracy: 0.6484 - val_loss: 1.0545 - val_accuracy: 0.5683
# Epoch 11/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.8900 - accuracy: 0.
# 6/6 [==============================] - 0s 3ms/step
# Epoch 11: Train F1-Score = 0.6253, Val F1-Score = 0.5451
# 23/23 [==============================] - 1s 27ms/step - loss: 0.8816 - accuracy: 0.6498 - val_loss: 1.0685 - val_accuracy: 0.5738
# Epoch 12/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.8683 - accuracy: 0.
# 6/6 [==============================] - 0s 3ms/step
# Epoch 12: Train F1-Score = 0.6230, Val F1-Score = 0.5431
# 23/23 [==============================] - 1s 25ms/step - loss: 0.8716 - accuracy: 0.6471 - val_loss: 1.0442 - val_accuracy: 0.5683
# Epoch 13/50
# 23/23 [==============================] - 0s 2ms/steposs: 0.8468 - accuracy: 0.
# 6/6 [==============================] - 0s 3ms/step
# Epoch 13: Train F1-Score = 0.6494, Val F1-Score = 0.5588
# 23/23 [==============================] - 1s 26ms/step - loss: 0.8609 - accuracy: 0.6498 - val_loss: 1.0437 - val_accuracy: 0.5847
# Epoch 14/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.8349 - accuracy: 0.
# 6/6 [==============================] - 0s 3ms/step
# Epoch 14: Train F1-Score = 0.6362, Val F1-Score = 0.5478
# 23/23 [==============================] - 1s 27ms/step - loss: 0.8549 - accuracy: 0.6607 - val_loss: 1.0446 - val_accuracy: 0.5738
# Epoch 15/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.8478 - accuracy: 0.
# 6/6 [==============================] - 0s 3ms/step
# Epoch 15: Train F1-Score = 0.6422, Val F1-Score = 0.5431
# 23/23 [==============================] - 1s 29ms/step - loss: 0.8461 - accuracy: 0.6566 - val_loss: 1.0423 - val_accuracy: 0.5683
# Epoch 16/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.7928 - accuracy: 0.
# 6/6 [==============================] - 0s 3ms/step
# Epoch 16: Train F1-Score = 0.6469, Val F1-Score = 0.5493
# 23/23 [==============================] - 1s 26ms/step - loss: 0.8421 - accuracy: 0.6689 - val_loss: 1.0325 - val_accuracy: 0.5738
# Epoch 17/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.7996 - accuracy: 0.
# 6/6 [==============================] - 0s 3ms/step
# Epoch 17: Train F1-Score = 0.6515, Val F1-Score = 0.5384
# 23/23 [==============================] - 1s 27ms/step - loss: 0.8349 - accuracy: 0.6566 - val_loss: 1.0393 - val_accuracy: 0.5628
# Epoch 18/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.8407 - accuracy: 0.
# 6/6 [==============================] - 0s 3ms/step
# Epoch 18: Train F1-Score = 0.6583, Val F1-Score = 0.5703
# 23/23 [==============================] - 1s 27ms/step - loss: 0.8258 - accuracy: 0.6799 - val_loss: 1.0264 - val_accuracy: 0.5956
# Epoch 19/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.8217 - accuracy: 0.
# 6/6 [==============================] - 0s 4ms/step
# Epoch 19: Train F1-Score = 0.6626, Val F1-Score = 0.5548
# 23/23 [==============================] - 1s 46ms/step - loss: 0.8183 - accuracy: 0.6635 - val_loss: 1.0265 - val_accuracy: 0.5792
# Epoch 20/50
# 23/23 [==============================] - 0s 2ms/steposs: 0.7765 - accuracy: 0.69
# 6/6 [==============================] - 0s 1ms/step
# Epoch 20: Train F1-Score = 0.6681, Val F1-Score = 0.5548
# 23/23 [==============================] - 1s 27ms/step - loss: 0.8069 - accuracy: 0.6785 - val_loss: 1.0363 - val_accuracy: 0.5792
# Epoch 21/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.7870 - accuracy: 0.
# 6/6 [==============================] - 0s 4ms/step
# Epoch 21: Train F1-Score = 0.6588, Val F1-Score = 0.5553
# 23/23 [==============================] - 1s 25ms/step - loss: 0.7991 - accuracy: 0.6785 - val_loss: 1.0387 - val_accuracy: 0.5792
# Epoch 22/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.7756 - accuracy: 0.
# 6/6 [==============================] - 0s 4ms/step
# Epoch 22: Train F1-Score = 0.6779, Val F1-Score = 0.5609
# 23/23 [==============================] - 1s 29ms/step - loss: 0.7903 - accuracy: 0.6813 - val_loss: 1.0218 - val_accuracy: 0.5847
# Epoch 23/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.7763 - accuracy: 0.
# 6/6 [==============================] - 0s 3ms/step
# Epoch 23: Train F1-Score = 0.6756, Val F1-Score = 0.5610
# 23/23 [==============================] - 1s 27ms/step - loss: 0.7850 - accuracy: 0.6881 - val_loss: 1.0397 - val_accuracy: 0.5847
# Epoch 24/50
# 23/23 [==============================] - 0s 2ms/steposs: 0.7601 - accuracy: 0.69
# 6/6 [==============================] - 0s 6ms/step
# Epoch 24: Train F1-Score = 0.6834, Val F1-Score = 0.5708
# 23/23 [==============================] - 1s 26ms/step - loss: 0.7811 - accuracy: 0.6881 - val_loss: 1.0201 - val_accuracy: 0.5956
# Epoch 25/50
# 23/23 [==============================] - 0s 2ms/steposs: 0.7803 - accuracy: 0.68
# 6/6 [==============================] - 0s 3ms/step
# Epoch 25: Train F1-Score = 0.6778, Val F1-Score = 0.5665
# 23/23 [==============================] - 1s 25ms/step - loss: 0.7762 - accuracy: 0.6854 - val_loss: 1.0284 - val_accuracy: 0.5902
# Epoch 26/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.7815 - accuracy: 0.
# 6/6 [==============================] - 0s 3ms/step
# Epoch 26: Train F1-Score = 0.6672, Val F1-Score = 0.5495
# 23/23 [==============================] - 1s 27ms/step - loss: 0.7695 - accuracy: 0.6949 - val_loss: 1.0628 - val_accuracy: 0.5738
# Epoch 27/50
# 23/23 [==============================] - 0s 2ms/steposs: 0.7487 - accuracy: 0.70
# 6/6 [==============================] - 0s 5ms/step
# Epoch 27: Train F1-Score = 0.6866, Val F1-Score = 0.5553
# 23/23 [==============================] - 1s 26ms/step - loss: 0.7701 - accuracy: 0.6977 - val_loss: 1.0420 - val_accuracy: 0.5792
# Epoch 28/50
# 23/23 [==============================] - 0s 2ms/steposs: 0.7616 - accuracy: 0.
# 6/6 [==============================] - 0s 5ms/step
# Epoch 28: Train F1-Score = 0.6829, Val F1-Score = 0.5607
# 23/23 [==============================] - 1s 25ms/step - loss: 0.7580 - accuracy: 0.7045 - val_loss: 1.0374 - val_accuracy: 0.5847
# Epoch 29/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.7403 - accuracy: 0.
# 6/6 [==============================] - 0s 7ms/step
# Epoch 29: Train F1-Score = 0.7040, Val F1-Score = 0.5886
# 23/23 [==============================] - 1s 26ms/step - loss: 0.7442 - accuracy: 0.6977 - val_loss: 1.0220 - val_accuracy: 0.6120
# Epoch 30/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.7605 - accuracy: 0.
# 6/6 [==============================] - 0s 2ms/step
# Epoch 30: Train F1-Score = 0.6900, Val F1-Score = 0.5662
# 23/23 [==============================] - 1s 26ms/step - loss: 0.7364 - accuracy: 0.7059 - val_loss: 1.0466 - val_accuracy: 0.5902
# Epoch 31/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.7443 - accuracy: 0.
# 6/6 [==============================] - 0s 5ms/step
# Epoch 31: Train F1-Score = 0.7103, Val F1-Score = 0.5779
# 23/23 [==============================] - 1s 28ms/step - loss: 0.7318 - accuracy: 0.7114 - val_loss: 1.0270 - val_accuracy: 0.6011
# Epoch 32/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.7207 - accuracy: 0.
# 6/6 [==============================] - 0s 3ms/step
# Epoch 32: Train F1-Score = 0.6907, Val F1-Score = 0.5555
# 23/23 [==============================] - 1s 29ms/step - loss: 0.7220 - accuracy: 0.7127 - val_loss: 1.0536 - val_accuracy: 0.5792
# Epoch 33/50
# 23/23 [==============================] - 0s 2ms/steposs: 0.7197 - accuracy: 0.
# 6/6 [==============================] - 0s 3ms/step
# Epoch 33: Train F1-Score = 0.7110, Val F1-Score = 0.5718
# 23/23 [==============================] - 1s 27ms/step - loss: 0.7202 - accuracy: 0.7114 - val_loss: 1.0499 - val_accuracy: 0.5956
# Epoch 34/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.7268 - accuracy: 0.
# 6/6 [==============================] - 0s 5ms/step
# Epoch 34: Train F1-Score = 0.7119, Val F1-Score = 0.5719
# 23/23 [==============================] - 1s 27ms/step - loss: 0.7103 - accuracy: 0.7182 - val_loss: 1.0467 - val_accuracy: 0.5956
# Epoch 35/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.7155 - accuracy: 0.
# 6/6 [==============================] - 0s 5ms/step
# Epoch 35: Train F1-Score = 0.7182, Val F1-Score = 0.5770
# 23/23 [==============================] - 1s 26ms/step - loss: 0.7015 - accuracy: 0.7168 - val_loss: 1.0531 - val_accuracy: 0.6011
# Epoch 36/50
# 23/23 [==============================] - 0s 2ms/steposs: 0.6795 - accuracy: 0.73
# 6/6 [==============================] - 0s 3ms/step
# Epoch 36: Train F1-Score = 0.7164, Val F1-Score = 0.5611
# 23/23 [==============================] - 1s 26ms/step - loss: 0.6928 - accuracy: 0.7278 - val_loss: 1.0483 - val_accuracy: 0.5847
# Epoch 37/50
# 23/23 [==============================] - 0s 2ms/steposs: 0.6972 - accuracy: 0.
# 6/6 [==============================] - 0s 4ms/step
# Epoch 37: Train F1-Score = 0.7223, Val F1-Score = 0.5602
# 23/23 [==============================] - 1s 26ms/step - loss: 0.6797 - accuracy: 0.7346 - val_loss: 1.0705 - val_accuracy: 0.5847
# Epoch 38/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.6932 - accuracy: 0.
# 6/6 [==============================] - 0s 6ms/step
# Epoch 38: Train F1-Score = 0.7231, Val F1-Score = 0.5572
# 23/23 [==============================] - 1s 25ms/step - loss: 0.6780 - accuracy: 0.7360 - val_loss: 1.0508 - val_accuracy: 0.5792
# Epoch 39/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.6782 - accuracy: 0.
# 6/6 [==============================] - 0s 3ms/step
# Epoch 39: Train F1-Score = 0.7328, Val F1-Score = 0.5670
# 23/23 [==============================] - 1s 31ms/step - loss: 0.6702 - accuracy: 0.7278 - val_loss: 1.0636 - val_accuracy: 0.5902
# Epoch 40/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.6667 - accuracy: 0.
# 6/6 [==============================] - 0s 4ms/step
# Epoch 40: Train F1-Score = 0.7292, Val F1-Score = 0.5780
# 23/23 [==============================] - 1s 28ms/step - loss: 0.6621 - accuracy: 0.7387 - val_loss: 1.0535 - val_accuracy: 0.6011
# Epoch 41/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.6612 - accuracy: 0.
# 6/6 [==============================] - 0s 3ms/step
# Epoch 41: Train F1-Score = 0.7305, Val F1-Score = 0.5680
# 23/23 [==============================] - 1s 24ms/step - loss: 0.6541 - accuracy: 0.7415 - val_loss: 1.0659 - val_accuracy: 0.5902
# Epoch 42/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.6360 - accuracy: 0.
# 6/6 [==============================] - 0s 4ms/step
# Epoch 42: Train F1-Score = 0.7310, Val F1-Score = 0.5710
# 23/23 [==============================] - 1s 29ms/step - loss: 0.6488 - accuracy: 0.7360 - val_loss: 1.0841 - val_accuracy: 0.5956
# Epoch 43/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.6560 - accuracy: 0.
# 6/6 [==============================] - 0s 2ms/step
# Epoch 43: Train F1-Score = 0.7422, Val F1-Score = 0.5831
# 23/23 [==============================] - 1s 28ms/step - loss: 0.6505 - accuracy: 0.7401 - val_loss: 1.0775 - val_accuracy: 0.6066
# Epoch 44/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.6436 - accuracy: 0.
# 6/6 [==============================] - 0s 4ms/step
# Epoch 44: Train F1-Score = 0.7508, Val F1-Score = 0.5476
# 23/23 [==============================] - 1s 28ms/step - loss: 0.6361 - accuracy: 0.7469 - val_loss: 1.0732 - val_accuracy: 0.5683
# Epoch 45/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.6341 - accuracy: 0.
# 6/6 [==============================] - 0s 3ms/step
# Epoch 45: Train F1-Score = 0.7488, Val F1-Score = 0.5641
# 23/23 [==============================] - 1s 27ms/step - loss: 0.6250 - accuracy: 0.7538 - val_loss: 1.0888 - val_accuracy: 0.5847
# Epoch 46/50
# 23/23 [==============================] - 0s 2ms/steposs: 0.5870 - accuracy: 0.75
# 6/6 [==============================] - 0s 1ms/step
# Epoch 46: Train F1-Score = 0.7486, Val F1-Score = 0.5697
# 23/23 [==============================] - 1s 28ms/step - loss: 0.6134 - accuracy: 0.7565 - val_loss: 1.0727 - val_accuracy: 0.5902
# Epoch 47/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.6142 - accuracy: 0.
# 6/6 [==============================] - 0s 3ms/step
# Epoch 47: Train F1-Score = 0.7466, Val F1-Score = 0.5780
# 23/23 [==============================] - 1s 26ms/step - loss: 0.6120 - accuracy: 0.7442 - val_loss: 1.1110 - val_accuracy: 0.6011
# Epoch 48/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.6045 - accuracy: 0.
# 6/6 [==============================] - 0s 3ms/step
# Epoch 48: Train F1-Score = 0.7498, Val F1-Score = 0.5699
# 23/23 [==============================] - 1s 29ms/step - loss: 0.6054 - accuracy: 0.7661 - val_loss: 1.1007 - val_accuracy: 0.5902
# Epoch 49/50
# 23/23 [==============================] - 0s 3ms/steposs: 0.6035 - accuracy: 0.
# 6/6 [==============================] - 0s 4ms/step
# Epoch 49: Train F1-Score = 0.7597, Val F1-Score = 0.5698
# 23/23 [==============================] - 1s 27ms/step - loss: 0.5979 - accuracy: 0.7524 - val_loss: 1.0943 - val_accuracy: 0.5902
# Epoch 50/50
# 23/23 [==============================] - 0s 2ms/steposs: 0.5961 - accuracy: 0.76
# 6/6 [==============================] - 0s 4ms/step
# Epoch 50: Train F1-Score = 0.7651, Val F1-Score = 0.5639
# 23/23 [==============================] - 1s 24ms/step - loss: 0.5832 - accuracy: 0.7729 - val_loss: 1.1100 - val_accuracy: 0.5847
# 8/8 [==============================] - 0s 4ms/step
# Test Accuracy: 0.5764
# Test F1-Score: 0.5616

# %% [markdown]
# ### **Answer to Question 13: F1-Score as a New Metric**
#
# The **F1-score** is a valuable metric for evaluating classification models, especially when dealing with imbalanced datasets like the Wine Quality dataset. Unlike accuracy, which only measures the overall correctness of predictions, the F1-score balances **precision** (how many predicted positives are actually correct) and **recall** (how many actual positives are correctly predicted). This makes it particularly useful for identifying performance issues with minority classes, which are often overlooked when using accuracy alone.
#
# #### **Training and Validation F1-Score**
# During training, the model’s F1-score on the training data improved significantly, starting at **0.4131** in the first epoch and reaching **0.7651** by the 50th epoch. This indicates that the model is learning and improving its ability to correctly classify the training data. However, the validation F1-score, which measures performance on unseen data, started at **0.3817** and only reached **0.5639** by the final epoch. The gap between the training and validation F1-scores suggests that the model is **overfitting**—it performs well on the training data but struggles to generalize to new data.
#
# #### **Test Set Performance**
# On the test set, the model achieved an **accuracy of 57.64%** and an **F1-score of 56.16%**. The slightly lower F1-score compared to accuracy indicates that the model’s performance is not uniform across all classes. Specifically, it struggles with minority classes (e.g., wines with very high or very low quality scores), where precision and recall are lower. This is a common issue in imbalanced datasets, where the model tends to favor the majority classes.
#
# #### **Why F1-Score Matters**
# The F1-score provides a more nuanced evaluation of the model’s performance than accuracy. For example:
# - A high accuracy but low F1-score suggests the model is good at predicting majority classes but performs poorly on minority classes.
# - A balanced F1-score indicates that the model is performing well across all classes, even if the overall accuracy is lower.
#
# #### **Conclusion**
# By using the **F1-score** as a metric, we gain a deeper understanding of the model’s performance, particularly for imbalanced datasets. While the model achieves reasonable accuracy, the F1-score reveals areas for improvement, especially in handling minority classes. Addressing these issues through techniques like regularization, class weighting, and hyperparameter tuning can lead to a more robust and balanced model.
